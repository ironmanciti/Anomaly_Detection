# %% [markdown]
# # Autoencoder 와 지도학습 모델을 이용한 신용카드 Fraud Detection
#
# - [Credit Card Fraud Detection](https://www.kaggle.com/mlg-ulb/creditcardfraud) - Kaggle
#
#
# - Highly Imbalanced Dataset - dataset는 2013 년 9 월 유럽 카드 소지자 신용 카드 거래로 만들었습니다. 이 dataset는 2 일 동안 발생한 거래를 보여 주며, 284,807 건의 거래 중 492 건의 fraud가 있습니다. 데이터세트는 매우 불균형하며 포지티브 클래스(사기)는 모든 거래의 0.172 %를 차지합니다.
#
#
# - 이 dataset는 PCA 변환의 결과인 숫자 입력 변수만 포함합니다. 안타깝게도 기밀 유지 문제로 인해 데이터에 대한 원래 feature와 추가 background 정보를 제공할 수 없습니다. 특성 V1, V2, ... V28은 PCA로 얻은 principal component이며 PCA로 변환되지 않은 유일한 특성은 'Time' 과 'Amount' 입니다. 'time' 특성은 각 트랜잭션과 데이터 세트의 첫 번째 트랜잭션 사이에 경과된 시간(초) 입니다. 'Amount' 특성은 거래금액 입니다.
#
#
#
# - 'Class'는 사기의 경우 1, 그렇지 않으면 0 입니다.
#
# - Colab 에서 실행

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import plot_model

import warnings
warnings.filterwarnings('ignore')

np.random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# ## Downloading of dataset

# %%
df = pd.read_csv( 'https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# - 이 데이터셋은 극도록 편향되어 있습니다.

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# 'Class' 열에서 사기(Fraud) 데이터의 개수를 계산합니다. 사기는 'Class' 값이 1인 경우입니다.
fraud = (df['Class'] == 1).sum()

# 'Class' 열에서 정상(Normal) 데이터의 개수를 계산합니다. 정상 데이터는 'Class' 값이 0인 경우입니다.
normal = (df['Class'] == 0).sum()

# 전체 데이터의 개수를 계산합니다. 사기 데이터와 정상 데이터의 합입니다.
total = fraud + normal

print(f"Total = {total:,}")

# 전체 데이터에 대한 백분율로 계산하여 출력합니다.
print(f"Fraud = {fraud/total*100:,.2f}%")
print(f"Normal = {normal/total*100:,.2f}%")
# Out:
# Total = 284,807
# Fraud = 0.17%
# Normal = 99.83%

# %% [markdown]
# - Time 필드를 일중 시간으로 변환합니다.
# - Amount 필드는 로그 스케일로 변환합니다.

# %%
# 'Time' 열의 값을 일중 시간 형식으로 변환합니다.
# 각 값 x를 3600(초)로 나누어 시간 단위로 변환하고, 24로 나눈 나머지 값을 계산합니다.
# 이는 시간을 24시간 형식으로 맞추기 위해 사용됩니다.
df.loc[:, "Time"] = df.loc[:, "Time"].apply(lambda x: x / 3600 % 24)

# 'Amount' 열의 값을 로그 변환합니다.
# 로그 변환을 위해 각 값에 1을 더한 후 자연 로그를 계산합니다.
# 이는 데이터의 분포를 정규 분포에 가깝게 만들어 모델 학습에 도움이 되도록 하기 위함입니다.
df.loc[:, 'Amount'] = np.log(df.loc[:, 'Amount'] + 1)

# %% [markdown]
# - class 1 이 너무 적으므로 통상적인 7:3 대신 5:5 비율로 train, test set 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class', axis=1), df['Class'],
                                                    test_size=0.5, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((142403, 30), (142404, 30), (142403,), (142404,))

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train.values)
X_test  = sc.transform(X_test.values)

# %%
# Train set의 정상/사기 거래 비율
y_train.value_counts() / y_train.count()
# Out:
# Class
# 0    0.998251
# 1    0.001749
# Name: count, dtype: float64

# %%
# Test set 의 정상/사기 거래 비율
y_test.value_counts() / y_test.count()
# Out:
# Class
# 0    0.998294
# 1    0.001706
# Name: count, dtype: float64

# %% [markdown]
# ## Autoencoder Train

# %% [markdown]
# - 모든 데이터를 이용하여 autoencoder 학습
#
# - Autoencoder 의 encoder 부분을 feature extractor 로 이용

# %% [markdown]
# ## autoencoder의 인코더 부분 및 k-NN / SVC 사용
#
# 훈련 데이터세트의 모든 사례 (사기/정상)를 사용하여 훈련하고 그 결과를 사용하여 인스턴스들을 12 차원 공간에 매핑합니다. 매핑된 케이스는 분류를 위해 k-NN, SVM, DNN 모델에 공급됩니다.

# %% [markdown]
# ### Auto Encoder model 작성
# - encoder 부분만 사용할 수 있도록 encoder 와 decoder network 을 분리하여 작성
# - decoder는 훈련된 encoder를 얻기 위한 역할

# %%
# 입력 레이어를 정의합니다. 입력 데이터의 형태는 30차원입니다.
input_layer = Input(shape=(30, ))

# 인코더(Encoder) 레이어를 정의합니다.
encoded_all = Dense(12, activation='relu')(input_layer)

# 디코더(Decoder) 레이어를 정의합니다.
decoded_all = Dense(30)(encoded_all)

# 인코더 모델을 정의합니다.
encoder_all = Model(input_layer, encoded_all)

# 오토인코더(Autoencoder) 모델을 정의합니다.
autoencoder_all = Model(input_layer, decoded_all)

# %%
plot_model(autoencoder_all, show_shapes=True)

# %%
autoencoder_all.compile(optimizer='adam', loss='mse')

history = autoencoder_all.fit(X_train, X_train, epochs = 30,
                              batch_size=128, validation_data=(X_test, X_test))
# Out:
# Epoch 1/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.9141 - val_loss: 0.6048
# Epoch 2/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5884 - val_loss: 0.5607
# Epoch 3/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5582 - val_loss: 0.5563
# Epoch 4/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5541 - val_loss: 0.5557
# Epoch 5/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5528 - val_loss: 0.5561
# Epoch 6/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5523 - val_loss: 0.5566
# Epoch 7/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5519 - val_loss: 0.5571
# Epoch 8/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5516 - val_loss: 0.5575
# Epoch 9/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.5513 - val_loss: 0.5579
# Epoch 10/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5510 - val_loss: 0.5582
# Epoch 11/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5508 - val_loss: 0.5585
# Epoch 12/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5506 - val_loss: 0.5588
# Epoch 13/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5504 - val_loss: 0.5590
# Epoch 14/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5502 - val_loss: 0.5591
# Epoch 15/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5501 - val_loss: 0.5593
# Epoch 16/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5500 - val_loss: 0.5594
# Epoch 17/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5498 - val_loss: 0.5595
# Epoch 18/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5497 - val_loss: 0.5596
# Epoch 19/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5496 - val_loss: 0.5597
# Epoch 20/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5496 - val_loss: 0.5598
# Epoch 21/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5495 - val_loss: 0.5599
# Epoch 22/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5494 - val_loss: 0.5600
# Epoch 23/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5493 - val_loss: 0.5600
# Epoch 24/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5493 - val_loss: 0.5601
# Epoch 25/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5492 - val_loss: 0.5602
# Epoch 26/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5492 - val_loss: 0.5602
# Epoch 27/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5491 - val_loss: 0.5603
# Epoch 28/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5491 - val_loss: 0.5603
# Epoch 29/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5491 - val_loss: 0.5603
# Epoch 30/30
# 1113/1113 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5490 - val_loss: 0.5604

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# ## KNN, SVC
# - train input 으로 사용하기 위한 encoder output 출력

# %%
enc_all = encoder_all.predict(X_train)
enc_all.shape
# Out:
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# (142403, 12)

# %% [markdown]
# - encoder output 을 feature 로 이용하여 knn, svc model train

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# 서포트 벡터 머신(SVM) 모델을 생성합니다.
model_svc = SVC()

# k-NN 분류기를 생성합니다.
model_knn = KNeighborsClassifier(n_neighbors=3)

# %%
# training set을 encoder에 통과시켜 얻은 feature를 이용하여 model 훈련
model_svc.fit(enc_all, y_train)
# Out:
# SVC()

# %%
model_knn.fit(enc_all, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# - train 된 모델을 이용하여 test set 분류

# %%
# %%time
# encoder_all 모델은 입력 데이터를 압축된 표현(저차원 공간)으로 변환합니다.
encoded_test_data = encoder_all.predict(X_test)

# SVM 모델을 사용하여 인코더 모델의 출력 대해 클래스 레이블을 예측합니다.
predicted_svc = model_svc.predict(encoded_test_data)

# 예측된 클래스 레이블을 출력합니다.
print(predicted_svc)
# Out:
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# [0 0 0 ... 0 0 0]
# CPU times: user 15.2 s, sys: 577 ms, total: 15.7 s
# Wall time: 14.5 s

# %%
# %%time
# k-NN 모델을 사용하여 인코더 모델의 출력 대해 클래스 레이블을 예측합니다.
predicted_knn = model_knn.predict(encoded_test_data)

# 예측된 클래스 레이블을 출력합니다.
print(predicted_knn)
# Out:
# [0 0 0 ... 0 0 0]
# CPU times: user 52.2 s, sys: 753 ms, total: 53 s
# Wall time: 52.4 s

# %% [markdown]
# ### DNN 이진 분류 모델 작성

# %%
model_dnn = tf.keras.Sequential([
      tf.keras.layers.Input(shape=(enc_all.shape[-1],)),
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(1, activation='sigmoid'),
  ])

model_dnn.compile(
      optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
      loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
# encoder_all 모델은 입력 데이터를 압축된 표현(저차원 공간)으로 변환합니다.
enc_test = encoder_all.predict(X_test)

enc_test.shape
# Out:
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# (142404, 12)

# %%
history = model_dnn.fit(enc_all, y_train, epochs=50, batch_size=1024,
                    validation_data=(enc_test, y_test))
# Out:
# Epoch 1/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9973 - loss: 0.1548 - val_accuracy: 0.9983 - val_loss: 0.0363
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9982 - loss: 0.0397 - val_accuracy: 0.9983 - val_loss: 0.0150
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9981 - loss: 0.0192 - val_accuracy: 0.9985 - val_loss: 0.0083
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9982 - loss: 0.0119 - val_accuracy: 0.9988 - val_loss: 0.0071
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9984 - loss: 0.0112 - val_accuracy: 0.9989 - val_loss: 0.0066
# Epoch 6/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9985 - loss: 0.0107 - val_accuracy: 0.9990 - val_loss: 0.0062
# Epoch 7/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9986 - loss: 0.0083 - val_accuracy: 0.9991 - val_loss: 0.0058
# Epoch 8/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9988 - loss: 0.0077 - val_accuracy: 0.9992 - val_loss: 0.0055
# Epoch 9/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9987 - loss: 0.0079 - val_accuracy: 0.9992 - val_loss: 0.0052
# Epoch 10/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9987 - loss: 0.0071 - val_accuracy: 0.9992 - val_loss: 0.0049
# Epoch 11/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9987 - loss: 0.0065 - val_accuracy: 0.9992 - val_loss: 0.0047
# Epoch 12/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9989 - loss: 0.0063 - val_accuracy: 0.9992 - val_loss: 0.0046
# Epoch 13/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9988 - loss: 0.0059 - val_accuracy: 0.9993 - val_loss: 0.0045
# Epoch 14/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9989 - loss: 0.0055 - val_accuracy: 0.9993 - val_loss: 0.0044
# Epoch 15/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9990 - loss: 0.0055 - val_accuracy: 0.9993 - val_loss: 0.0043
# Epoch 16/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9989 - loss: 0.0053 - val_accuracy: 0.9992 - val_loss: 0.0043
# Epoch 17/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9990 - loss: 0.0054 - val_accuracy: 0.9993 - val_loss: 0.0042
# Epoch 18/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0054 - val_accuracy: 0.9992 - val_loss: 0.0042
# Epoch 19/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9990 - loss: 0.0054 - val_accuracy: 0.9993 - val_loss: 0.0041
# Epoch 20/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9990 - loss: 0.0050 - val_accuracy: 0.9993 - val_loss: 0.0040
# Epoch 21/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9990 - loss: 0.0050 - val_accuracy: 0.9993 - val_loss: 0.0040
# Epoch 22/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0047 - val_accuracy: 0.9993 - val_loss: 0.0040
# Epoch 23/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0048 - val_accuracy: 0.9993 - val_loss: 0.0040
# Epoch 24/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0049 - val_accuracy: 0.9993 - val_loss: 0.0039
# Epoch 25/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0048 - val_accuracy: 0.9993 - val_loss: 0.0039
# Epoch 26/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0046 - val_accuracy: 0.9993 - val_loss: 0.0039
# Epoch 27/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0046 - val_accuracy: 0.9993 - val_loss: 0.0038
# Epoch 28/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0045 - val_accuracy: 0.9993 - val_loss: 0.0038
# Epoch 29/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0046 - val_accuracy: 0.9993 - val_loss: 0.0038
# Epoch 30/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0047 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 31/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0044 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 32/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0044 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 33/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0040 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 34/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0038 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 35/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 36/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0044 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 37/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0040 - val_accuracy: 0.9993 - val_loss: 0.0036
# Epoch 38/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0044 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 39/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0038 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 40/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0045 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 41/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0044 - val_accuracy: 0.9993 - val_loss: 0.0037
# Epoch 42/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9993 - val_loss: 0.0035
# Epoch 43/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0039 - val_accuracy: 0.9993 - val_loss: 0.0036
# Epoch 44/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0043 - val_accuracy: 0.9994 - val_loss: 0.0035
# Epoch 45/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.9994 - val_loss: 0.0035
# Epoch 46/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0040 - val_accuracy: 0.9993 - val_loss: 0.0036
# Epoch 47/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9993 - val_loss: 0.0036
# Epoch 48/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0042 - val_accuracy: 0.9994 - val_loss: 0.0035
# Epoch 49/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0040 - val_accuracy: 0.9993 - val_loss: 0.0035
# Epoch 50/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0039 - val_accuracy: 0.9993 - val_loss: 0.0035

# %%
predicted_dnn = model_dnn.predict(encoder_all.predict(X_test)) > 0.5
predicted_dnn.shape
# Out:
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# (142404, 1)

# %% [markdown]
# 분류기로 사용한 전통적 머신러닝 2 개 모델과 딥러닝 모델의 성능 비교

# %%
for model, predicted in [("svc", predicted_svc),
                         ("knn", predicted_knn),
                         ("dnn", predicted_dnn)]:

    # 정밀도(Precision)를 계산하여 출력합니다.
    print("Precision {:.2f}".format(precision_score(y_test, predicted)))
    # 재현율(Recall)을 계산하여 출력합니다.
    print("Recall {:.2f}".format(recall_score(y_test, predicted)))

    # 혼동 행렬(confusion matrix)을 계산합니다.
    cm = confusion_matrix(y_test, predicted)

    # 혼동 행렬을 히트맵으로 시각화합니다.
    ax = sns.heatmap(cm, annot=True, fmt=',')

    # x축 레이블을 설정합니다.
    ax.set_xlabel('Predicted labels')

    # y축 레이블을 설정합니다.
    ax.set_ylabel('True labels')

    # 그래프의 제목을 설정합니다. 제목은 모델의 이름입니다.
    ax.set_title(model)

    # x축 틱 레이블을 설정합니다.
    ax.xaxis.set_ticklabels(['Normal', 'Fraud'])

    # y축 틱 레이블을 설정합니다.
    ax.yaxis.set_ticklabels(['Normal', 'Fraud'])

    # 틱 위치를 설정합니다.
    ax.set(yticks=[0.5, 1.5], xticks=[0.5, 1.5])

    # 그래프를 화면에 표시합니다.
    plt.show()
# Out:
# Precision 0.93
# Recall 0.68
# Precision 0.93
# Recall 0.73
# Precision 0.86
# Recall 0.73

# %% [markdown]
# ### 실습 문제
#
# - 오토인코더 구조 변경 :
# 현재 사용된 Autoencoder 구조를 변경해보고, 성능(Accuracy, Precision, Recall)이 어떻게 달라지는지 비교해보세요.
#
#     기존: 입력 30 → 중간 14 → 출력 30
#     변경 A: 30 → 10 → 30
#     변경 B: 30 → 8 → 4 → 8 → 30 (딥 오토인코더)
