# %% [markdown]
# # 시계열 데이터의 Anomaly Detection 방법 비교
#
# - RNN을 이용한 지도학습 방법 - 이진 분류
# - Autoencoder 사용 방법 - 재구성 오류 측정
# - Variational Autoencoder 사용 방법 - 재구성 오류 측정

# %%
# !pip install tensorflow==2.15.0

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score
from tensorflow.keras import layers, losses
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# - 이 연습문제에서는 RNN, 자동 인코더 및 변형 자동 인코더를 사용하여 [ECG5000 데이터 세트](http://www.timeseriesclassification.com/description.php?Dataset=ECG5000)에서 이상을 감지합니다.  이 데이터 세트에는 각각 140개의 데이터 포인트가 있는 5,000개의 심전도가 포함되어 있습니다. 각 예제에 0(비정상 리듬에 해당) 또는 1(정상 리듬에 해당)로 레이블이 지정된 데이터 세트의 단순화된 버전을 사용할 것입니다. 우리는 비정상적인 리듬을 식별하는 데 관심이 있습니다.
#
# - "ECG5000" 데이터셋은 Physionet에서 다운로드한 20시간 길이의 ECG 데이터로, BIDMC 심부전 데이터베이스(chfdb)의 "chf07" 기록입니다. 이 데이터는 원래 **Goldberger**와 여러 연구자들이 참여한 논문 "PhysioBank, PhysioToolkit, and PhysioNet: 복잡한 생리학적 신호를 위한 새로운 연구 자원의 구성 요소"에서 발표되었습니다. 데이터 전처리는 두 가지 단계로 이루어졌습니다: (1) 각 심박을 추출하고, (2) 각 심박의 길이를 보간(interpolation)으로 동일하게 맞췄습니다. 이 데이터셋은 원래 **"A general framework for never-ending learning from time series streams"** 논문(DAMI 29(6))에서 사용되었으며, 이후 5,000개의 심박이 무작위로 선택되었습니다. 환자는 심각한 울혈성 심부전을 앓고 있었으며, 클래스 값은 자동으로 주석이 추가되었습니다.

# %% [markdown]
# ## Load and prepare ECG data

# %%
# Dataset Download
df = pd.read_csv('http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv', header=None)
df
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1    -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2    -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3     0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4     0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
# ...        ...       ...       ...       ...       ...       ...       ...
# 4993  0.608558 -0.335651 -0.990948 -1.784153 -2.626145 -2.957065 -2.931897
# 4994 -2.060402 -2.860116 -3.405074 -3.748719 -3.513561 -3.006545 -2.234850
# 4995 -1.122969 -2.252925 -2.867628 -3.358605 -3.167849 -2.638360 -1.664162
# 4996 -0.547705 -1.889545 -2.839779 -3.457912 -3.929149 -3.966026 -3.492560
# 4997 -1.351779 -2.209006 -2.520225 -3.061475 -3.065141 -3.030739 -2.622720
#
#            7         8         9    ...       131       132       133  \
# 0    -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958
# 1    -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490
# 2    -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377
# 3    -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345
# 4    -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025
# ...        ...       ...       ...  ...       ...       ...       ...
# 4993 -2.664816 -2.090137 -1.461841  ...  1.757705  2.291923  2.704595
# 4994 -1.593270 -1.075279 -0.976047  ...  1.388947  2.079675  2.433375
# 4995 -0.935655 -0.866953 -0.645363  ... -0.472419 -1.310147 -2.029521
# 4996 -2.695270 -1.849691 -1.374321  ...  1.258419  1.907530  2.280888
# 4997 -2.044092 -1.295874 -0.733839  ... -1.512234 -2.076075 -2.586042
#
#            134       135       136       137       138       139  140
# 0     0.578621  0.257740  0.228077  0.123431  0.925286  0.193137  1.0
# 1     0.724046  0.555784  0.476333  0.773820  1.119621 -1.436250  1.0
# 2    -0.021919 -0.713683 -0.532197  0.321097  0.904227 -0.421797  1.0
# 3     0.842069  0.952074  0.990133  1.086798  1.403011 -0.383564  1.0
# 4     1.371682  1.277392  0.960304  0.971020  1.614392  1.421456  1.0
# ...        ...       ...       ...       ...       ...       ...  ...
# 4993  2.451519  2.017396  1.704358  1.688542  1.629593  1.342651  0.0
# 4994  2.159484  1.819747  1.534767  1.696818  1.483832  1.047612  0.0
# 4995 -3.221294 -4.176790 -4.009720 -2.874136 -2.008369 -1.808334  0.0
# 4996  1.895242  1.437702  1.193433  1.261335  1.150449  0.804932  0.0
# 4997 -3.322799 -3.627311 -3.437038 -2.260023 -1.577823 -0.684531  0.0
#
# [4998 rows x 141 columns]

# %%
df.iloc[:, -1].value_counts()
# Out:
# 140
# 1.0    2919
# 0.0    2079
# Name: count, dtype: int64

# %%
# 데이터프레임의 마지막 열에 해당하는 레이블(정답)을 가져옵니다.
labels = df.iloc[:, -1]

# 심전도 데이터의 특성(feature) 값들을 가져옵니다.
data = df.iloc[:, 0:-1]

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3998, 140), (1000, 140), (3998,), (1000,))

# %%
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
y_train = y_train.astype(bool)
y_test = y_test.astype(bool)

# %% [markdown]
# normal, abnormal data 분리

# %%
# y_train이 True인 경우, 즉 정상 데이터에 해당하는 X_train, X_test, y_train, y_test 데이터를 각각 추출
normal_X_train = X_train[y_train]
normal_X_test = X_test[y_test]
normal_y_train = y_train[y_train]
normal_y_test = y_test[y_test]

# y_train이 False인 경우, 즉 비정상 데이터에 해당하는 X_train, X_test, y_train, y_test 데이터를 각각 추출
abnormal_X_train = X_train[~y_train]
abnormal_X_test = X_test[~y_test]
abnormal_y_train = y_train[~y_train]
abnormal_y_test = y_test[~y_test]

# 정상 데이터와 비정상 데이터의 shape 출력
print("정상 데이터", normal_X_train.shape, normal_X_test.shape,
      normal_y_train.shape, normal_y_test.shape)
print("비정상 데이터", abnormal_X_train.shape, abnormal_X_test.shape,
      abnormal_y_train.shape, abnormal_y_test.shape)
# Out:
# 정상 데이터 (2328, 140) (591, 140) (2328,) (591,)
# 비정상 데이터 (1670, 140) (409, 140) (1670,) (409,)

# %%
# 정상 학습 데이터를 TensorFlow Dataset으로 변환하고, 무작위로 섞은 후 배치 크기 128로 분할
train_ds = tf.data.Dataset.from_tensor_slices(normal_X_train).shuffle(10000).batch(128)

# 정상 테스트 데이터를 TensorFlow Dataset으로 변환하고, 배치 크기 128로 분할
test_ds = tf.data.Dataset.from_tensor_slices(normal_X_test).batch(128)

# %% [markdown]
# 정상 ECG 시각화

# %%
# 한 줄에 10개의 서브플롯을 생성합니다.
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 3))

# 각 서브플롯에 대해 ECG 데이터를 플롯합니다.
for i in range(10):
    axes[i].plot(normal_X_train[i])
    axes[i].set_title(f"A normal ECG #{i+1}")
    axes[i].grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# 비정상 ECG 시각화

# %%
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 3))

# 각 서브플롯에 대해 ECG 데이터를 플롯합니다.
for i in range(10):
    axes[i].plot(abnormal_X_train[i])
    axes[i].set_title(f"A normal ECG #{i+1}")
    axes[i].grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 이상 탐지를 위한 RNN
# 데이터 세트의 레이블에 액세스할 수 있으므로 이상 감지를 이진 분류 지도 학습 문제로 설정할 수 있습니다.

# %%
# RNN 모델 입력에 맞게 X_train 데이터에 새로운 차원을 추가하여 3D 텐서로 변환
X_train_rnn = np.expand_dims(X_train, axis=2)

# RNN 모델 입력에 맞게 X_test 데이터에 새로운 차원을 추가하여 3D 텐서로 변환
X_test_rnn = np.expand_dims(X_test, axis=2)

# 변환된 X_train_rnn과 X_test_rnn의 shape 출력
X_train_rnn.shape, X_test_rnn.shape
# Out:
# ((3998, 140, 1), (1000, 140, 1))

# %%
# RNN 모델 생성
model = tf.keras.Sequential()
model.add(layers.LSTM(100, input_shape=(X_train_rnn.shape[1],X_train_rnn.shape[2])))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40901 (159.77 KB)
# Trainable params: 40901 (159.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam')
history = model.fit(X_train_rnn, y_train, epochs=20, batch_size=256)
# Out:
# Epoch 1/20
# 16/16 [==============================] - 4s 18ms/step - loss: 0.6500
# Epoch 2/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4772
# Epoch 3/20
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1978
# Epoch 4/20
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1487
# Epoch 5/20
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1379
# Epoch 6/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1226
# Epoch 7/20
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0905
# Epoch 8/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0896
# Epoch 9/20
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0842
# Epoch 10/20
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0820
# Epoch 11/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0890
# Epoch 12/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1042
# Epoch 13/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0945
# Epoch 14/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0863
# Epoch 15/20
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0792
# Epoch 16/20
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0726
# Epoch 17/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0738
# Epoch 18/20
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0738
# Epoch 19/20
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0763
# Epoch 20/20
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0692

# %%
plt.plot(history.history['loss'])
plt.title('Training Loss')
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
# Test set 정상/비정상 분류
preds = model.predict(X_test_rnn) > 0.5

# metric 계산
accuracy_test_rnn= accuracy_score(preds, y_test)
print('Accuracy = ',accuracy_test_rnn)

precision_test_rnn=precision_score(preds, y_test)
print('Precision = ',precision_test_rnn)

recall_test_rnn=recall_score(preds, y_test)
print('Recall = ',recall_test_rnn)
# Out:
# 32/32 [==============================] - 1s 6ms/step
# Accuracy =  0.979
# Precision =  0.9898477157360406
# Recall =  0.975

# %% [markdown]
# ### 이상 감지를 위한 오토인코더
# autoencoder의 목적은 주어진 입력의 재구성 오류를 최소화하는 것입니다. 따라서 우리는 최소한의 오류로 이러한 예를 재구성할 수 있도록 정상 심전도 시퀀스에 대해서만 자동 인코더를 훈련할 것입니다.
# 비정상적인 리듬은 정상 시퀀스보다 재구성 오류가 더 높아야 하므로 재구성 오류가 고정 임계값보다 높은 경우의 리듬을 이상으로 분류할 수 있습니다.

# %%
class AnomalyDetectorAE(Model):
    def __init__(self):
        super(AnomalyDetectorAE, self).__init__()

        # encoder network
        self.encoder = tf.keras.Sequential([
              Dense(32, activation="relu"),
              Dense(16, activation="relu"),
              Dense(8, activation="relu")])

        # decoder network
        self.decoder = tf.keras.Sequential([
              Dense(16, activation="relu"),
              Dense(32, activation="relu"),
              Dense(140, activation="sigmoid")])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

autoencoder = AnomalyDetectorAE()

# %%
autoencoder.compile(optimizer='adam', loss='mae')

# %% [markdown]
# 오토인코더는 정상 ECG만 사용하여 훈련됩니다.

# %%
history = autoencoder.fit(normal_X_train, normal_X_train,
                                      epochs=20, batch_size=256,
                                      validation_data=(normal_X_test, normal_X_test),
                                      shuffle=True)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 25ms/step - loss: 0.1374 - val_loss: 0.1292
# Epoch 2/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1209 - val_loss: 0.1097
# Epoch 3/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1012 - val_loss: 0.0898
# Epoch 4/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0823 - val_loss: 0.0727
# Epoch 5/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0671 - val_loss: 0.0609
# Epoch 6/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0572 - val_loss: 0.0539
# Epoch 7/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0516 - val_loss: 0.0504
# Epoch 8/20
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0488 - val_loss: 0.0483
# Epoch 9/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0472 - val_loss: 0.0473
# Epoch 10/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0463 - val_loss: 0.0467
# Epoch 11/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0459 - val_loss: 0.0464
# Epoch 12/20
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0456 - val_loss: 0.0461
# Epoch 13/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0455 - val_loss: 0.0460
# Epoch 14/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0453 - val_loss: 0.0458
# Epoch 15/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0451 - val_loss: 0.0456
# Epoch 16/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0449 - val_loss: 0.0454
# Epoch 17/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0446 - val_loss: 0.0449
# Epoch 18/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0442 - val_loss: 0.0444
# Epoch 19/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0436 - val_loss: 0.0438
# Epoch 20/20
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0429 - val_loss: 0.0428

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %% [markdown]
# 정상 데이터를 오토인코더로 인코딩과 디코딩을 한 후의 신호를 살펴봅니다.

# %%
# 오토인코더의 인코더를 사용하여 정상 테스트 데이터(normal_X_test)를 인코딩하여 잠재 공간 표현(encoded_signals) 생성
encoded_signals = autoencoder.encoder(normal_X_test).numpy()

# 오토인코더의 디코더를 사용하여 인코딩된 신호(encoded_signals)를 복원(decoded_signals)하여 원본 형태로 변환
decoded_signals = autoencoder.decoder(encoded_signals).numpy()

# 첫 번째 테스트 샘플의 원본 신호(normal_X_test[0])를 파란색 선으로 플롯
plt.plot(normal_X_test[0], 'b', label="Input")

# 첫 번째 테스트 샘플의 복원된 신호(decoded_signals[0])를 빨간색 선으로 플롯
plt.plot(decoded_signals[0], 'r', label="Reconstruction")

# 원본 신호와 복원된 신호 사이의 차이를 시각화하기 위해 채워진 영역을 추가 (오차 시각화)
plt.fill_between(np.arange(140), decoded_signals[0], normal_X_test[0],
                 color='lightcoral', label="Error")

# 범례 추가
plt.legend()
plt.show()

# %% [markdown]
# 비정상적 데이터 예제에 대한 유사한 플롯 만들기:

# %%
# 오토인코더의 인코더를 사용하여 비정상 테스트 데이터(abnormal_X_test)를 인코딩하여 잠재 공간 표현(encoded_signals) 생성
encoded_signals = autoencoder.encoder(abnormal_X_test).numpy()

# 오토인코더의 디코더를 사용하여 인코딩된 신호(encoded_signals)를 복원(decoded_signals)하여 원본 형태로 변환
decoded_signals = autoencoder.decoder(encoded_signals).numpy()

# 첫 번째 비정상 테스트 샘플의 원본 신호(abnormal_X_test[0])를 파란색 선으로 플롯
plt.plot(abnormal_X_test[0], 'b', label="Input")

# 첫 번째 비정상 테스트 샘플의 복원된 신호(decoded_signals[0])를 빨간색 선으로 플롯
plt.plot(decoded_signals[0], 'r', label="Reconstruction")

# 원본 신호와 복원된 신호 사이의 차이를 시각화하기 위해 채워진 영역을 추가 (오차 시각화)
plt.fill_between(np.arange(140), decoded_signals[0], abnormal_X_test[0],
                 color='lightcoral', label="Error")

# 범례 추가
plt.legend()
plt.show()

# %% [markdown]
# ### 이상 감지
# 재구성 손실이 고정 임계값보다 큰지 여부를 계산하여 이상을 감지합니다. 이를 위해 훈련 세트의 정상 예제에 대한 평균 평균 오류를 계산한 다음 재구성 오류가 훈련 세트의 표준 편차보다 높으면 미래 예제를 비정상적인 것으로 분류합니다.
#
# 훈련 세트의 정상 ECG에 대한 재구성 오류를 시각화 합니다.

# %%
# 오토인코더 모델을 사용하여 정상 학습 데이터(normal_X_train)에 대한 복원 결과(reconstructions) 생성
reconstructions = autoencoder.predict(normal_X_train)

# 정상 학습 데이터와 복원된 데이터 간의 MAE(Mean Absolute Error) 손실 계산
train_loss = tf.keras.losses.mae(reconstructions, normal_X_train).numpy()

# 학습 손실(train_loss)의 분포를 히스토그램으로 시각화
plt.hist(train_loss, bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()
# Out:
# 73/73 [==============================] - 0s 2ms/step

# %% [markdown]
# 평균 + 1 표준편차인 임계값을 선택합니다.

# %%
# 학습 손실(train_loss)의 평균과 표준편차를 이용하여 이상 탐지에 사용할 임계값(threshold_ae) 설정
threshold_ae = np.mean(train_loss) + np.std(train_loss)

# 설정된 임계값 출력
print("임계값 (Threshold): ", threshold_ae)
# Out:
# 임계값 (Threshold):  0.07012173533545132

# %% [markdown]
# 테스트 세트의 대부분의 비정상 example은 임계값보다 재구성 오류가 더 큽니다. 임계값을 변경하여 분류기의 정밀도와 재현율을 조정할 수 있습니다.

# %%
# 오토인코더 모델을 사용하여 비정상 학습 데이터(abnormal_X_train)에 대한 복원 결과(reconstructions) 생성
reconstructions = autoencoder.predict(abnormal_X_train)

# 비정상 학습 데이터와 복원된 데이터 간의 MAE(Mean Absolute Error) 손실 계산
test_loss = tf.keras.losses.mae(reconstructions, abnormal_X_train).numpy()

# 비정상 데이터의 복원 오차(test_loss) 분포를 히스토그램으로 시각화
plt.hist(test_loss, bins=50)

# 설정된 임계값(threshold_ae)을 빨간색 선으로 표시
plt.axvline(threshold_ae, c='r')

# 그래프 제목 및 축 레이블 설정
plt.title("Reconstruction Error of abnormal data")
plt.xlabel("Test loss")
plt.ylabel("No of examples")

# 그래프 표시
plt.show()
# Out:
# 53/53 [==============================] - 0s 2ms/step

# %% [markdown]
# 재구성 오류가 임계값보다 큰 경우 ECG를 이상으로 분류합니다.
# 재구성 오류를 이용한 이상치 예측과 label 을 비교하여 performance 를 측정합니다.

# %%
# 모델, 데이터 및 임계값을 입력으로 받아서 예측을 수행하는 함수
def predict(model, data, threshold):
    # 주어진 모델로 데이터를 복원하고, 원본 데이터와 복원 데이터 간의 MAE 손실 계산
    reconstructions = model.predict(data)
    loss = tf.keras.losses.mae(reconstructions, data)
    # 손실이 임계값(threshold)보다 작은 경우 True, 크면 False 반환 (정상/비정상 판별)
    return tf.math.less(loss, threshold)

# 예측 결과(predictions)와 실제 라벨(labels)을 입력으로 받아서 정확도, 정밀도, 재현율을 출력하는 함수
def print_stats(predictions, labels):
    # 정확도(Accuracy) 출력
    print("정확도 (Accuracy) = {:.2f}".format(accuracy_score(labels, predictions)))
    # 정밀도(Precision) 출력
    print("정밀도 (Precision) = {:.2f}".format(precision_score(labels, predictions)))
    # 재현율(Recall) 출력
    print("재현율 (Recall) = {:.2f}".format(recall_score(labels, predictions)))

# %%
preds = predict(autoencoder, X_test, threshold_ae)
print_stats(preds.numpy(), y_test)
# Out:
# 32/32 [==============================] - 0s 4ms/step
# 정확도 (Accuracy) = 0.95
# 정밀도 (Precision) = 0.99
# 재현율 (Recall) = 0.92

# %% [markdown]
# ### 이상 감지를 위한 Variational Autoencoder
# 오토인코더는 훈련 데이터에 과적합되는 경향이 강합니다. 이 문제를 완화하도록 설계된 VAE를 사용합니다.

# %% [markdown]
# ### Sampling Class
#
# 먼저 'Sampling' 클래스를 빌드합니다. 이것은 인코더 출력의 평균 (mu) 및 표준 편차 (sigma)와 함께 가우스 노이즈 입력을 제공하는 맞춤형 Keras 레이어입니다. 실제로 이 레이어의 출력은 다음 방정식으로 제공됩니다.
#
# $$z = \mu + e^{0.5\sigma} * \epsilon  $$
#
# 여기서 $\mu$ = mean, $\sigma$ = standard deviation, $\epsilon$ = random sample

# %%
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        """인코더의 출력과 결합하여 무작위 샘플을 생성합니다.
        Args:
          inputs -- 인코더로부터의 출력 텐서 (평균 mu, 표준편차 sigma)
        Returns:
          무작위 샘플이 결합된 `inputs` 텐서
        """
        # 인코더의 출력을 분해합니다.
        mu, sigma = inputs

        # 배치의 크기와 차원을 얻습니다.
        batch = tf.shape(mu)[0]
        dim = tf.shape(mu)[1]

        # 무작위 텐서를 생성합니다.
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))

        # 재매개변수화 기법을 적용합니다.
        return mu + tf.math.exp(0.5 * sigma) * epsilon

# %% [markdown]
# ### Kullback–Leibler Divergence
# 모델의 생성 능력을 향상 시키려면 잠재 공간에 도입된 랜덤 정규 분포를 고려해야 합니다. 이를 위해 [Kullback–Leibler Divergence](https://arxiv.org/abs/2002.07514)가 계산되어 재구성 손실에 추가됩니다. 공식은 아래 함수에서 정의됩니다.

# %%
def kl_reconstruction_loss(inputs, outputs, mu, sigma):
    """Kullback-Leibler 발산(KLD) 계산
    Args:
    inputs -- 데이터셋 배치
    outputs -- Sampling 층의 출력
    mu -- 평균
    sigma -- 표준 편차

    Returns:
    KLD 손실
    """
    # KLD 계산 공식 적용
    kl_loss = 1 + sigma - tf.square(mu) - tf.math.exp(sigma)
    # 배치 내 평균을 계산하고 -0.5를 곱하여 최종 KLD 손실을 계산
    kl_loss = tf.reduce_mean(kl_loss) * -0.5

    return kl_loss

# %%
LATENT_DIM = 2
input_dim = normal_X_train.shape[-1]
input_dim
# Out:
# 140

# %% [markdown]
# 이제 전체 VAE 모델을 정의할 수 있습니다. KL reconstruction loss를 추가하기 위해 `model.add_loss()`를 사용합니다. 이 손실을 계산하는 것은 `y_true`와 `y_pred`를 사용하지 않으므로 `model.compile()`에서 사용할 수 없습니다.
#
# - add_loss() 메서드 : 손실이 있는 경우, 자동으로 합산되어 주 손실에 추가

# %%
# Encoder 정의
encoder_input = Input(shape=(input_dim,))
x = Dense(32, activation='relu')(encoder_input)
x = Dense(16, activation='relu')(x)
mu = Dense(LATENT_DIM)(x)
sigma = Dense(LATENT_DIM)(x)

z = Sampling()((mu, sigma))

encoder = Model(encoder_input, [mu, sigma, z])

# Decoder 정의
decoder_input = Input(shape=(LATENT_DIM,))
x = Dense(16, activation='relu')(decoder_input)
x = Dense(32, activation='relu')(x)
decoded = Dense(input_dim, activation='sigmoid')(x)

decoder = Model(decoder_input, decoded)

# %% [markdown]
# ### 변이형 오토인코더(VAE, Variational Autoencoder)를 구축하고 학습하기 위해 필요한 모델을 정의

# %%
vae_input = encoder_input
# 인코더를 통과시켜 평균(mu), 표준 편차(sigma), 그리고 잠재 공간의 벡터(z)를 얻습니다.
mu, sigma, z = encoder(vae_input)
# 디코더를 사용하여 잠재 공간의 벡터(z)로부터 입력을 재구성
reconstructed = decoder(z)

# 입력과 재구성된 값을 사용하여 VAE 모델을 생성
vae = Model(vae_input, reconstructed)
# Kullback-Leibler 발산을 계산하는 함수를 사용하여 손실을 추가합니다. 이는 잠재 공간의 분포가
# 우리가 원하는 분포(예: 표준 정규 분포)에 가까워지도록 돕습니다.
loss = kl_reconstruction_loss(vae_input, z, mu, sigma)
# add_loss는 사용자 정의 손실을 추가하는 메서드
vae.add_loss(loss)

# %%
learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

# 학습 과정에서의 평균 손실을 추적
loss_metric = tf.keras.metrics.Mean()
# 평균 제곱 오차 손실 함수를 사용합니다.
mse_loss = tf.keras.losses.MeanSquaredError()

# %%
epochs = 40

@tf.function
def train_step(x_batch_train):
    with tf.GradientTape() as tape:
        # VAE 모델에 배치 입력을 공급하여 재구성된 결과를 얻음
        reconstructed = vae(x_batch_train)

        # 재구성 손실을 계산
        loss = mse_loss(x_batch_train, reconstructed)

        # KLD 정규화 손실을 추가
        loss += sum(vae.losses)  # vae.losses에는 KLD 손실이 포함됨

    # 그라디언트를 계산하고 가중치 업데이트
    grads = tape.gradient(loss, vae.trainable_weights)
    optimizer.apply_gradients(zip(grads, vae.trainable_weights))
    return loss

# 테스트 스텝 추가
@tf.function
def test_step(x_batch_test):
    reconstructed = vae(x_batch_test)
    loss = mse_loss(x_batch_test, reconstructed)
    loss += sum(vae.losses)
    return loss

# 손실 지표를 두 개로 분리
train_loss_metric = tf.keras.metrics.Mean()
test_loss_metric = tf.keras.metrics.Mean()

for epoch in range(epochs):
    print('Start of epoch %d' % (epoch,))

    # 에포크 시작 시 지표 리셋
    train_loss_metric.reset_states()
    test_loss_metric.reset_states()

    for step, (x_batch_train, x_batch_test) in enumerate(zip(train_ds, test_ds)):
        # 훈련 스텝
        train_loss = train_step(x_batch_train)
        train_loss_metric(train_loss)

        # 테스트 스텝
        test_loss = test_step(x_batch_test)
        test_loss_metric(test_loss)

        # 매 500 스텝마다 결과 표시
        if step % 500 == 0:
            print('Epoch: %s step: %s' % (epoch, step))
            print('Mean training loss = %s' % (train_loss_metric.result().numpy()))
            print('Mean test loss = %s' % (test_loss_metric.result().numpy()))
# Out:
# Start of epoch 0
# Epoch: 0 step: 0
# Mean training loss = 0.31455982
# Mean test loss = 0.23518094
# Start of epoch 1
# Epoch: 1 step: 0
# Mean training loss = 0.06856948
# Mean test loss = 0.05042304
# Start of epoch 2
# Epoch: 2 step: 0
# Mean training loss = 0.031691324
# Mean test loss = 0.03070015
# Start of epoch 3
# Epoch: 3 step: 0
# Mean training loss = 0.028397322
# Mean test loss = 0.027429521
# Start of epoch 4
# Epoch: 4 step: 0
# Mean training loss = 0.025501007
# Mean test loss = 0.025124552
# Start of epoch 5
# Epoch: 5 step: 0
# Mean training loss = 0.0230015
# Mean test loss = 0.023056837
# Start of epoch 6
# Epoch: 6 step: 0
# Mean training loss = 0.02118764
# Mean test loss = 0.021511773
# Start of epoch 7
# Epoch: 7 step: 0
# Mean training loss = 0.019056836
# Mean test loss = 0.018559305
# Start of epoch 8
# Epoch: 8 step: 0
# Mean training loss = 0.017490935
# Mean test loss = 0.016850408
# Start of epoch 9
# Epoch: 9 step: 0
# Mean training loss = 0.014460051
# Mean test loss = 0.01473818
# Start of epoch 10
# Epoch: 10 step: 0
# Mean training loss = 0.0128171705
# Mean test loss = 0.013176145
# Start of epoch 11
# Epoch: 11 step: 0
# Mean training loss = 0.011491006
# Mean test loss = 0.011767113
# Start of epoch 12
# Epoch: 12 step: 0
# Mean training loss = 0.0104755955
# Mean test loss = 0.010172824
# Start of epoch 13
# Epoch: 13 step: 0
# Mean training loss = 0.009710694
# Mean test loss = 0.009822935
# Start of epoch 14
# Epoch: 14 step: 0
# Mean training loss = 0.009403164
# Mean test loss = 0.008679423
# Start of epoch 15
# Epoch: 15 step: 0
# Mean training loss = 0.007387438
# Mean test loss = 0.008085504
# Start of epoch 16
# Epoch: 16 step: 0
# Mean training loss = 0.008662932
# Mean test loss = 0.008051663
# Start of epoch 17
# Epoch: 17 step: 0
# Mean training loss = 0.006722116
# Mean test loss = 0.007834862
# Start of epoch 18
# Epoch: 18 step: 0
# Mean training loss = 0.0067055523
# Mean test loss = 0.0071951137
# Start of epoch 19
# Epoch: 19 step: 0
# Mean training loss = 0.0070945704
# Mean test loss = 0.007218909
# Start of epoch 20
# Epoch: 20 step: 0
# Mean training loss = 0.0060293996
# Mean test loss = 0.006799186
# Start of epoch 21
# Epoch: 21 step: 0
# Mean training loss = 0.0070138993
# Mean test loss = 0.0068983557
# Start of epoch 22
# Epoch: 22 step: 0
# Mean training loss = 0.006826232
# Mean test loss = 0.006687685
# Start of epoch 23
# Epoch: 23 step: 0
# Mean training loss = 0.006871928
# Mean test loss = 0.0066674417
# Start of epoch 24
# Epoch: 24 step: 0
# Mean training loss = 0.006376026
# Mean test loss = 0.006380962
# Start of epoch 25
# Epoch: 25 step: 0
# Mean training loss = 0.0059341243
# Mean test loss = 0.0062237466
# Start of epoch 26
# Epoch: 26 step: 0
# Mean training loss = 0.00745562
# Mean test loss = 0.006236911
# Start of epoch 27
# Epoch: 27 step: 0
# Mean training loss = 0.006950562
# Mean test loss = 0.0061827735
# Start of epoch 28
# Epoch: 28 step: 0
# Mean training loss = 0.006283078
# Mean test loss = 0.0061083464
# Start of epoch 29
# Epoch: 29 step: 0
# Mean training loss = 0.005132444
# Mean test loss = 0.006132009
# Start of epoch 30
# Epoch: 30 step: 0
# Mean training loss = 0.005215791
# Mean test loss = 0.0060619153
# Start of epoch 31
# Epoch: 31 step: 0
# Mean training loss = 0.006366087
# Mean test loss = 0.0060330317
# Start of epoch 32
# Epoch: 32 step: 0
# Mean training loss = 0.005946657
# Mean test loss = 0.005901098
# Start of epoch 33
# Epoch: 33 step: 0
# Mean training loss = 0.005024993
# Mean test loss = 0.005942677
# Start of epoch 34
# Epoch: 34 step: 0
# Mean training loss = 0.0053730956
# Mean test loss = 0.0057170056
# Start of epoch 35
# Epoch: 35 step: 0
# Mean training loss = 0.005208549
# Mean test loss = 0.0056917924
# Start of epoch 36
# Epoch: 36 step: 0
# Mean training loss = 0.0054243254
# Mean test loss = 0.0055578146
# Start of epoch 37
# Epoch: 37 step: 0
# Mean training loss = 0.005403952
# Mean test loss = 0.005580563
# Start of epoch 38
# Epoch: 38 step: 0
# Mean training loss = 0.006943084
# Mean test loss = 0.0055017597
# Start of epoch 39
# Epoch: 39 step: 0
# Mean training loss = 0.0052776076
# Mean test loss = 0.005580824

# %% [markdown]
# ## Reconstruction Error 시각화

# %%
# VAE(Variational Autoencoder) 모델을 사용하여 테스트 데이터(X_test)의 복원된 이미지를 예측
decoded_imgs = vae.predict(X_test)

# 첫 번째 테스트 샘플의 원본 데이터(normal_X_test[0])를 파란색 선으로 플롯
plt.plot(normal_X_test[0], 'b', label="Input")

# 첫 번째 테스트 샘플의 복원된 데이터(decoded_imgs[0])를 빨간색 선으로 플롯
plt.plot(decoded_imgs[0], 'r', label="Reconstruction")

# 원본 데이터와 복원된 데이터 사이의 차이를 시각화하기 위해 채워진 영역을 추가 (오차 시각화)
plt.fill_between(np.arange(140), decoded_imgs[0], normal_X_test[0],
                 color='lightcoral', label="Error")

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %% [markdown]
# 이전과 마찬가지로 평균 절대 오차에 표준 편차 1을 더한 값에서 임계값을 계산합니다.

# %%
# VAE 모델을 사용하여 정상 학습 데이터(normal_X_train)에 대한 복원 결과(reconstructions) 생성
reconstructions = vae.predict(normal_X_train)

# 원본 데이터(normal_X_train)와 복원된 데이터(reconstructions) 간의 MAE(Mean Absolute Error) 손실 계산
train_loss = tf.keras.losses.mae(reconstructions, normal_X_train).numpy()

# 학습 손실(train_loss)의 분포를 히스토그램으로 시각화
plt.hist(train_loss, bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()
# Out:
# 73/73 [==============================] - 0s 3ms/step

# %%
# 학습 손실(train_loss)의 평균과 표준편차를 이용하여 VAE의 이상 탐지 임계값(threshold_vae) 설정
threshold_vae = np.mean(train_loss) + np.std(train_loss)

# 설정된 임계값 출력
print("임계값 (Threshold): ", threshold_vae)
# Out:
# 임계값 (Threshold):  0.07914638393230956

# %%
# VAE 모델을 사용하여 비정상 테스트 데이터(abnormal_X_test)에 대한 복원 결과 생성
reconstructions = vae.predict(abnormal_X_test)

# 원본 데이터(abnormal_X_test)와 복원된 데이터(reconstructions) 간의 MAE(Mean Absolute Error) 손실 계산
test_loss = tf.keras.losses.mae(reconstructions, abnormal_X_test).numpy()

# 테스트 손실(test_loss)의 분포를 히스토그램으로 시각화
plt.hist(test_loss, bins=50)

# 설정된 임계값(threshold_vae)을 빨간색 선으로 표시
plt.axvline(threshold_vae, c='r')

# 그래프의 x축과 y축 레이블 설정
plt.xlabel("Test loss")
plt.ylabel("No of examples")

# 그래프 표시
plt.show()
# Out:
# 13/13 [==============================] - 0s 3ms/step

# %% [markdown]
# 재구성 오류가 임계값보다 큰 경우 ECG를 이상으로 분류합니다.

# %% [markdown]
# ### variational autoencoder를 이용한 예측

# %%
preds = predict(vae, X_test, threshold_vae)
print("Variational Autoencoder")
print_stats(preds, y_test)
# Out:
# 32/32 [==============================] - 0s 2ms/step
# Variational Autoencoder
# 정확도 (Accuracy) = 0.93
# 정밀도 (Precision) = 0.98
# 재현율 (Recall) = 0.91

# %% [markdown]
# ### autoencoder를 이용한 예측

# %%
preds = predict(autoencoder, X_test, threshold_ae)
print("Autoencoder")
print_stats(preds, y_test)
# Out:
# 32/32 [==============================] - 0s 3ms/step
# Autoencoder
# 정확도 (Accuracy) = 0.95
# 정밀도 (Precision) = 0.99
# 재현율 (Recall) = 0.92

# %% [markdown]
# RNN 이진 분류 모델

# %%
print("RNN 을 이용한 분류")
print('Accuracy = ',accuracy_test_rnn)
print('Precision = ',precision_test_rnn)
print('Recall = ',recall_test_rnn)
# Out:
# RNN 을 이용한 분류
# Accuracy =  0.979
# Precision =  0.9898477157360406
# Recall =  0.975
