# %% [markdown]
# # Autoencoder Reconstruction Error를 이용한 Fraud Detection
#
# - [Credit Card Fraud Detection](https://www.kaggle.com/mlg-ulb/creditcardfraud) - Kaggle
#
#
# - Highly Imbalanced Dataset - dataset는 2013 년 9 월 유럽 카드 소지자 신용 카드 거래로 만들었습니다. 이 dataset는 2 일 동안 발생한 거래를 보여 주며, 284,807 건의 거래 중 492 건의 fraud가 있습니다. 데이터세트는 매우 불균형하며 포지티브 클래스(사기)는 모든 거래의 0.172 %를 차지합니다.
#
#
# - 이 dataset는 PCA 변환의 결과인 숫자 입력 변수만 포함합니다. 안타깝게도 기밀 유지 문제로 인해 데이터에 대한 원래 feature와 추가 background 정보를 제공할 수 없습니다. 특성 V1, V2, ... V28은 PCA로 얻은 principal component이며 PCA로 변환되지 않은 유일한 특성은 `Time` 과 `Amount`입니다.`'Time` 특성은 각 트랜잭션과 데이터 세트의 첫 번째 트랜잭션 사이에 경과된 시간(초) 입니다. `Amount` 특성은 거래금액 입니다.
#
#
#
# - `Class`는 사기의 경우 1, 그렇지 않으면 0 입니다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import plot_model
import warnings
warnings.filterwarnings('ignore')

np.random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# ## 데이터셋 다운로드

# %%
df = pd.read_csv( 'https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# - 이 데이터셋은 극도로 편향되어 있습니다.

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# 'Class' 열에서 사기(Fraud) 데이터의 개수를 계산합니다. 사기는 'Class' 값이 1인 경우입니다.
fraud = (df['Class'] == 1).sum()

# 'Class' 열에서 정상(Normal) 데이터의 개수를 계산합니다. 정상 데이터는 'Class' 값이 0인 경우입니다.
normal = (df['Class'] == 0).sum()

# 전체 데이터의 개수를 계산합니다. 사기 데이터와 정상 데이터의 합입니다.
total = fraud + normal

# 전체 데이터 개수를 천 단위로 구분하여 출력합니다.
print(f"Total = {total:,}")

# 사기 데이터의 비율을 전체 데이터에 대한 백분율로 계산하여 출력합니다.
print(f"Fraud = {fraud/total*100:,.2f}%")

# 정상 데이터의 비율을 전체 데이터에 대한 백분율로 계산하여 출력합니다.
print(f"Normal = {normal/total*100:,.2f}%")
# Out:
# Total = 284,807
# Fraud = 0.17%
# Normal = 99.83%

# %% [markdown]
# - Time 필드를 일중 시간으로 변환합니다.
# - Amount 필드는 로그 스케일로 변환합니다.

# %%
# 'Time' 열의 값을 24시간 형식으로 변환합니다.
# 각 값 x를 3600(초)로 나누어 시간 단위로 변환하고, 24로 나눈 나머지 값을 계산합니다.
# 이는 시간을 24시간 형식으로 맞추기 위해 사용됩니다.
df.loc[:, "Time"] = df.loc[:, "Time"].apply(lambda x: x / 3600 % 24)

# 'Amount' 열의 값을 로그 변환합니다.
# 0이나 음수 값이 되는 것을 방지하기 위해 각 값에 1을 더한 후 자연 로그를 계산합니다.
# 이는 데이터의 분포를 정규 분포에 가깝게 만들어 모델 학습에 도움이 되도록 하기 위함입니다.
df.loc[:, 'Amount'] = np.log(df.loc[:, 'Amount'] + 1)

# %% [markdown]
# - class 1 이 너무 적으므로 통상적인 7:3 대신 5:5 비율로 train, test set 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(
                        df.drop('Class', axis=1), df['Class'],
                        test_size=0.5, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((142403, 30), (142404, 30), (142403,), (142404,))

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train.values)
X_test  = sc.transform(X_test.values)

# %%
# y_train 데이터의 각 클래스 값의 개수를 계산한 후, 전체 개수로 나누어 비율을 계산합니다.
# value_counts() 메서드는 각 클래스 값의 개수를 계산합니다.
# count() 메서드는 전체 데이터의 개수를 계산합니다.
# 각 클래스의 개수를 전체 개수로 나누어 비율을 계산합니다.
class_ratios = y_train.value_counts() / y_train.count()
class_ratios
# Out:
# Class
# 0    0.998251
# 1    0.001749
# Name: count, dtype: float64

# %%
y_test.value_counts() / y_test.count()
# Out:
# Class
# 0    0.998294
# 1    0.001706
# Name: count, dtype: float64

# %% [markdown]
# ## Autoencoder Train

# %% [markdown]
# - 정상 거래로만 오토 인코더를 교육합니다.
#
# - 사기성(비정상) 거래의 재구성 error 가 비사기성 거래보다 높을 것으로 기대합니다.

# %%
# y_train이 0인 샘플만 선택하여 정상 데이터(X_train_normal)를 생성합니다.
X_train_normal = X_train[y_train == 0]

# y_train이 1인 샘플만 선택하여 사기 데이터(X_train_fraud)를 생성합니다.
X_train_fraud = X_train[y_train == 1]

# 정상 데이터와 사기 데이터의 형태(shape)를 출력합니다.
print(X_train_normal.shape, X_train_fraud.shape)
# Out:
# (142154, 30) (249, 30)

# %%
# y_test가 0인 샘플만 선택하여 정상 데이터(X_test_normal)를 생성합니다.
X_test_normal = X_test[y_test == 0]

# y_test가 1인 샘플만 선택하여 사기 데이터(X_test_fraud)를 생성합니다.
X_test_fraud = X_test[y_test == 1]

# 정상 데이터와 사기 데이터의 형태(shape)를 출력합니다.
print(X_test_normal.shape, X_test_fraud.shape)
# Out:
# (142161, 30) (243, 30)

# %% [markdown]
# ## DNN model 작성
# - 정상 데이터만 사용

# %%
# 입력 레이어를 정의합니다. 입력 데이터의 형태는 30차원입니다.
input_layer = Input(shape=(30, ))

# 인코더(Encoder) 레이어를 정의합니다.
encoded_normal = Dense(12, activation='relu')(input_layer)

# 디코더(Decoder) 레이어를 정의합니다.
decoded_normal = Dense(30, activation='linear')(encoded_normal)

# 오토인코더(Autoencoder) 모델을 정의합니다.
autoencoder_normal = Model(input_layer, decoded_normal)

# %%
autoencoder_normal.compile(optimizer='adam', loss='mse')

# %%
plot_model(autoencoder_normal, show_shapes=True)

# %% [markdown]
# ### 정상 data로 만 train

# %%
history = autoencoder_normal.fit(X_train_normal, X_train_normal,
                                 epochs = 30, batch_size=128,
                            validation_data=(X_test_normal, X_test_normal))
# Out:
# Epoch 1/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.8854 - val_loss: 0.5692
# Epoch 2/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5567 - val_loss: 0.5278
# Epoch 3/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5273 - val_loss: 0.5229
# Epoch 4/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5233 - val_loss: 0.5224
# Epoch 5/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5221 - val_loss: 0.5223
# Epoch 6/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5214 - val_loss: 0.5223
# Epoch 7/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5208 - val_loss: 0.5223
# Epoch 8/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5203 - val_loss: 0.5224
# Epoch 9/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5199 - val_loss: 0.5224
# Epoch 10/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5195 - val_loss: 0.5224
# Epoch 11/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5192 - val_loss: 0.5224
# Epoch 12/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5189 - val_loss: 0.5224
# Epoch 13/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5187 - val_loss: 0.5225
# Epoch 14/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5185 - val_loss: 0.5225
# Epoch 15/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5183 - val_loss: 0.5225
# Epoch 16/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5181 - val_loss: 0.5226
# Epoch 17/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5179 - val_loss: 0.5226
# Epoch 18/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5178 - val_loss: 0.5226
# Epoch 19/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5176 - val_loss: 0.5226
# Epoch 20/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5175 - val_loss: 0.5226
# Epoch 21/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5174 - val_loss: 0.5226
# Epoch 22/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5172 - val_loss: 0.5226
# Epoch 23/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5171 - val_loss: 0.5227
# Epoch 24/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5170 - val_loss: 0.5227
# Epoch 25/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5169 - val_loss: 0.5227
# Epoch 26/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5168 - val_loss: 0.5227
# Epoch 27/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5168 - val_loss: 0.5228
# Epoch 28/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5167 - val_loss: 0.5228
# Epoch 29/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5166 - val_loss: 0.5228
# Epoch 30/30
# 1111/1111 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5166 - val_loss: 0.5228

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# ## Reconstruction Error 시각화
#
# - Anomaly data 와의 bar chart 비교를 위해 정상 abnormal data 갯수 만큼의 임의의 normal sample 을 선택

# %%
# np.random.choice 함수는 X_train_normal의 길이만큼 범위에서 250개의 고유한 인덱스를 무작위로 선택합니다.
# replace=False는 중복 없이 샘플을 선택하도록 합니다.
indices = np.random.choice(len(X_train_normal), 250, replace=False)

# 선택된 인덱스를 사용하여 X_train_normal에서 샘플을 추출합니다.
Nom_data = X_train_normal[indices]

Nom_data.shape
# Out:
# (250, 30)

# %% [markdown]
# ### 정상 data 및 fraud data 의 autoencoder 재 구성값
# - 정상 data의 metric

# %%
 # AE 결과값
Nom_pred = autoencoder_normal.predict(Nom_data, verbose=0)
# input - output 간의 MSE 구하기
Nom_pred_mse = np.mean(np.power(Nom_data - Nom_pred, 2), axis=1)

print('정상 데이터의 Metric')
Nom_pred_mse_df = pd.DataFrame({'Normal_mse': Nom_pred_mse})
Nom_pred_mse_df.describe()
# Out:
# 정상 데이터의 Metric
#        Normal_mse
# count  250.000000
# mean     0.457536
# std      1.020342
# min      0.081095
# 25%      0.217871
# 50%      0.315809
# 75%      0.452724
# max     15.100784

# %% [markdown]
# - fraud data의 metric

# %%
# AE 결과값
ANom_pred = autoencoder_normal.predict(X_train_fraud, verbose=0)
# input - output 간의 MSE 구하기
ANom_pred_mse = np.mean(np.power(X_train_fraud - ANom_pred, 2), axis=1)

print('Fraud 데이터의 Metric')
ANom_pred_mse_df = pd.DataFrame({'Anomaly_mse': ANom_pred_mse})
ANom_pred_mse_df.describe()
# Out:
# Fraud 데이터의 Metric
#        Anomaly_mse
# count   249.000000
# mean     22.919601
# std      29.041782
# min       0.122115
# 25%       4.070243
# 50%       8.865828
# 75%      26.359814
# max     163.256530

# %% [markdown]
# - 정상 data 와 anomaly data 간의 MSE 차이 시각화

# %%
plt.title('MSE compare')

# 정상 데이터의 MSE 히스토그램을 그립니다.
# bins=10은 히스토그램의 막대 수를 10으로 설정합니다.
# color='blue'는 막대의 색상을 파란색으로 설정합니다.
# histtype='step'은 막대의 외곽선만 그립니다.
# label='normal'은 범례에 표시될 레이블을 설정합니다.
plt.hist(Nom_pred_mse, bins=10, color='blue', histtype='step', label='normal')

# 비정상 데이터의 MSE 히스토그램을 그립니다.
# bins=10은 히스토그램의 막대 수를 10으로 설정합니다.
# color='red'는 막대의 색상을 빨간색으로 설정합니다.
# histtype='step'은 막대의 외곽선만 그립니다.
# label='abnormal'은 범례에 표시될 레이블을 설정합니다.
plt.hist(ANom_pred_mse, bins=10, color='red', histtype='step', label='abnormal')

plt.xlabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# - 정상, 비정상 data 의 box plot 비교

# %%
# Nom_pred_mse와 ANom_pred_mse 데이터를 사용하여 박스 플롯을 생성합니다.
plt.boxplot([Nom_pred_mse, ANom_pred_mse])

# x축의 틱(tick) 위치와 레이블을 설정합니다.
# ticks=[1, 2]는 x축의 틱 위치를 1과 2로 설정합니다.
# labels=['Normal', 'Fraud']는 각각의 틱 위치에 대응하는 레이블을 'Normal'과 'Fraud'로 설정합니다.
plt.xticks(ticks=[1, 2], labels=['Normal', 'Fraud'])

plt.title('Normal vs Fraud')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# ## Reconstruction error threshold 결정
#
# - 정상 data 로만 train 한 autoencoder model 의 재구성 결과의 원본과의 mse 차이를 기준으로 사기 거래 분류

# %%
# 정상 데이터로만 훈련시킨 오토인코더 모델을 사용하여 X_train 데이터에 대한 예측을 수행합니다.
# predictions 은 오토인코더가 압축 --> 복원한 값
predictions = autoencoder_normal.predict(X_train)

# 원본 데이터(X_train)와 복원된 데이터(predictions) 간의 MSE(Mean Squared Error)를 계산합니다.
# np.power(X_train - predictions, 2)은 원본 데이터와 예측된 데이터의 차이를 제곱합니다.
# np.mean(..., axis=1)은 각 샘플에 대해 제곱 차이의 평균을 계산합니다.
mse = np.mean(np.power(X_train - predictions, 2), axis=1)

# 재구성 오차와 실제 클래스를 포함하는 데이터프레임을 생성합니다.
error_df = pd.DataFrame({'reconstruction_error': mse, 'true_class': y_train})
error_df.head()
# Out:
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
#         reconstruction_error  true_class
# 269414              1.169192           0
# 75463               0.119344           0
# 99307               0.100417           0
# 212267              0.896430           0
# 157412              0.319550           0

# %%
# 'true_class'를 기준으로 그룹화하여 각 클래스에 대한 통계 정보를 계산합니다.
# describe() 메서드는 각 그룹에 대해 재구성 오차(reconstruction_error)의 통계 값을 계산합니다.
desc = error_df.groupby('true_class').describe()
desc
# Out:
#            reconstruction_error                                            \
#                           count       mean        std       min       25%
# true_class
# 0                      142154.0   0.518008   1.792285  0.030766  0.224407
# 1                         249.0  22.919601  29.041782  0.122115  4.070243
#
#
#                  50%        75%         max
# true_class
# 0           0.322743   0.470905  159.674041
# 1           8.865828  26.359814  163.256530

# %% [markdown]
# - 위에서 볼 수 있듯이 사기성이 아닌 경우의 오류는 사기성 사례의 오류보다 낮습니다.
#
#
# - mean + 3 * std 를 threshold 로 사용하여 test set 의 재구성 error (squared error) 가 threshold 보다 크면 fraud 거래로 분류합니다.
#
# <div align="center">
#
# | 시그마 범위      | 포함 비율    | 이상치로 간주 비율     |
# |------------------|--------------|--------------------------|
# | ±1σ (1시그마)     | 약 68%       | 32% 이상치 가능성       |
# | ±2σ (2시그마)     | 약 95%       | 5% 이상치 가능성        |
# | ±2.5σ            | 약 98.8%     | 1.2% 이상치 가능성      |
# | ±3σ (3시그마)     | 약 99.7%     | 0.3% 이상치 가능성      |
#
# </div>

# %%
# 정상 클래스(클래스 0)의 재구성 오류에 대한 평균과 표준편차을 계산합니다.
mean = desc['reconstruction_error']['mean'][0]
std = desc['reconstruction_error']['std'][0]

# 여러 시그마 수준에서의 임계값(threshold)을 계산합니다.
# 평균에 각 시그마 수준(3, 2.5, 2)에서 표준 편차의 배수를 더하여 임계값을 설정합니다.
# 시그마 임계값을 float로 변환해서 딕셔너리에 저장
thresholds = {
    "3sigma": float(mean + 3*std),
    "2.5sigma": float(mean + 2.5*std),
    "2sigma": float(mean + 2*std)
}

print("평균: {:.2f}, 표준편차: {:.2f}".format(mean,std))
print()
print(thresholds)
# Out:
# 평균: 0.52, 표준편차: 1.79
#
# {'3sigma': 5.894863097226427, '2.5sigma': 4.998720521872005, '2sigma': 4.102577946517584}

# %%
#  재구성 오차 리스트를 주어진 임계값(thresholds['3sigma'])과 비교하여 이상치 여부를 판단합니다.
# - 재구성 오차가 임계값 이상이면: 이상치 → 1
# - 재구성 오차가 임계값 미만이면: 정상치 → 0
# - 결과는 [0, 5, 10, 50, 150] 각 값에 대해 판단한 리스트로 반환됩니다.
# - 람다(lambda) 함수와 리스트 컴프리헨션을 함께 사용해 구현되었습니다.
result = [(lambda er: 1 if er >= thresholds['3sigma'] else 0)(er)
          for er in [0, 5, 10, 50, 150]]

result  # 예: [0, 0, 1, 1, 1] (임계값보다 큰 값들은 이상치로 판단)
# Out:
# [0, 0, 1, 1, 1]

# %% [markdown]
# - 재구성 오류를 이용한 anomaly detection
# - threshold 를 높일 수록 더 넓은 범위를 정상으로 인식하므로 recall 은 낮아집니다.  반면, 정말 확실한 것만 이상치로 인식하게 되므로 precision 은 높아집니다.
#
# - confusion matrix 시각화

# %%
# 임계값(thresholds)을 값에 따라 오름차순으로 정렬합니다.
# sorted() 함수와 lambda 함수를 사용하여 임계값을 기준으로 정렬합니다.
ths = sorted(thresholds.items(), key=lambda kv: kv[1])

# 각 임계값에 대해 반복합니다.
for k, threshold in ths:
    # 오토인코더 모델을 사용하여 X_test 데이터에 대한 복원을 수행합니다.
    test_predictions = autoencoder_normal.predict(X_test)

    # 원본 데이터(X_test)와 복원된 데이터(test_predictions) 간의 MSE(Mean Squared Error)를 계산합니다.
    mse = np.mean(np.power(X_test - test_predictions, 2), axis=1)

    # MSE 값이 임계값 이상이면 1, 그렇지 않으면 0으로 설정하여 예측된 레이블(y_pred)을 생성합니다.
    y_pred = [(lambda er: 1 if er >= threshold else 0)(er) for er in mse]

    # 정밀도(Precision)를 계산하여 출력합니다.
    print("Precision {:.2f}".format(precision_score(y_test, y_pred)))
    # 재현율(Recall)을 계산하여 출력합니다.
    print("Recall {:.2f}".format(recall_score(y_test, y_pred)))

    # 혼동 행렬(confusion matrix)을 계산합니다.
    cm = confusion_matrix(y_test, y_pred)

    # 혼동 행렬을 히트맵으로 시각화합니다.
    ax = sns.heatmap(cm, annot=True, fmt=',')
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.xaxis.set_ticklabels(['Normal', 'Fraud'])  # x축 틱 레이블을 설정합니다.
    ax.yaxis.set_ticklabels(['Normal', 'Fraud'])  # y축 틱 레이블을 설정합니다.
    ax.set(yticks=[0.5, 1.5], xticks=[0.5, 1.5])  # 틱 위치를 설정합니다.
    ax.set_title(k)       # 그래프의 제목을 임계값 키(k)로 설정합니다.
    plt.show()
# Out:
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Precision 0.12
# Recall 0.72
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Precision 0.14
# Recall 0.63
# 4451/4451 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Precision 0.16
# Recall 0.60

# %% [markdown]
# ### 실습 문제
#
# 오토인코더 구조 변경 실험
#
# 구조 A: 30 → 15 → 8 → 15 → 30
#
# 구조 B: 30 → 10 → 30 (더 압축)
#
# 구조 C: 30 → 25 → 30 (압축 없이 거의 그대로 복원)
#
# 각 경우에 대한 평가지표 비교:
#
# - Reconstruction Error 분포
# - Precision / Recall 변화
